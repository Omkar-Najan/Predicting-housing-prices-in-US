# %% [markdown]
# # Task 1: Introduction
#
# ---
#
# For this project, we are going to work on evaluating price of houses given the following features:
#
# 1. Year of sale of the house
# 2. The age of the house at the time of sale
# 3. Distance from city center
# 4. Number of stores in the locality
# 5. The latitude
# 6. The longitude
#
#
# Note: This notebook uses `python 3` and these packages: `tensorflow`, `pandas`, `matplotlib`, `scikit-learn`.

# %% [markdown]
# ## 1.1: Importing Libraries & Helper Functions
#
# First of all, we will need to import some libraries and helper functions. This includes TensorFlow and some utility functions that I've written to save time.

# %%
import pandas as pd
import matplotlib.pyplot as plt


from utils import *
from sklearn.model_selection import train_test_split


# %matplotlib inline


print('Libraries imported.')
# Out:
# Libraries imported.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, LambdaCallback
# tf.logging.set_verbosity(tf.logging.ERROR)

print('Libraries Imported')
# Out:
# Libraries Imported

# %% [markdown]
# # Task 2: Importing the Data

# %% [markdown]
# ## 2.1: Importing the Data
#
# The dataset is saved in a `data.csv` file. We will use `pandas` to take a look at some of the rows.

# %%
df = pd.read_csv('data.csv', names = column_names) 
df.head()
# Out:
#    serial  date  age  distance  stores  latitude  longitude  price
# 0       0  2009   21         9       6        84        121  14264
# 1       1  2007    4         2       3        86        121  12032
# 2       2  2016   18         3       7        90        120  13560
# 3       3  2002   13         2       2        80        128  12029
# 4       4  2014   25         5       8        81        122  14157

# %% [markdown]
# ## 2.2: Check Missing Data
#
# It's a good practice to check if the data has any missing values. In real world data, this is quite common and must be taken care of before any data pre-processing or model training.

# %%
df.isna().sum()
# Out:
# serial       0
# date         0
# age          0
# distance     0
# stores       0
# latitude     0
# longitude    0
# price        0
# dtype: int64

# %% [markdown]
# # Task 3: Data Normalization

# %% [markdown]
# ## 3.1: Data Normalization
#
# We can make it easier for optimization algorithms to find minimas by normalizing the data before training a model.

# %%
df = df.iloc[:,1:]
df_norm = (df - df.mean()) / df.std()
df_norm.head()
# Out:
#        date       age  distance    stores  latitude  longitude     price
# 0  0.015978  0.181384  1.257002  0.345224 -0.307212  -1.260799  0.350088
# 1 -0.350485 -1.319118 -0.930610 -0.609312  0.325301  -1.260799 -1.836486
# 2  1.298598 -0.083410 -0.618094  0.663402  1.590328  -1.576456 -0.339584
# 3 -1.266643 -0.524735 -0.930610 -0.927491 -1.572238   0.948803 -1.839425
# 4  0.932135  0.534444  0.006938  0.981581 -1.255981  -0.945141  0.245266

# %% [markdown]
# ## 3.2: Convert Label Value
#
# Because we are using normalized values for the labels, we will get the predictions back from a trained model in the same distribution. So, we need to convert the predicted values back to the original distribution if we want predicted prices.

# %%
y_mean = df['price'].mean()
y_std = df['price'].std()

def convert_label_value(pred):
    return int(pred * y_std + y_mean)

print(convert_label_value(0.350088))
# Out:
# 14263

# %% [markdown]
# # Task 4: Create Training and Test Sets

# %% [markdown]
# ## 4.1: Select Features
#
# Make sure to remove the column __price__ from the list of features as it is the label and should not be used as a feature.

# %%
X = df_norm.iloc[:, :6]
X.head()
# Out:
#        date       age  distance    stores  latitude  longitude
# 0  0.015978  0.181384  1.257002  0.345224 -0.307212  -1.260799
# 1 -0.350485 -1.319118 -0.930610 -0.609312  0.325301  -1.260799
# 2  1.298598 -0.083410 -0.618094  0.663402  1.590328  -1.576456
# 3 -1.266643 -0.524735 -0.930610 -0.927491 -1.572238   0.948803
# 4  0.932135  0.534444  0.006938  0.981581 -1.255981  -0.945141

# %% [markdown]
# ## 4.2: Select Labels

# %%
Y = df_norm.iloc[:, -1]
Y.head()
# Out:
# 0    0.350088
# 1   -1.836486
# 2   -0.339584
# 3   -1.839425
# 4    0.245266
# Name: price, dtype: float64

# %% [markdown]
# ## 4.3: Feature and Label Values
#
# We will need to extract just the numeric values for the features and labels as the TensorFlow model will expect just numeric values as input.

# %%
X_arr = X.values
Y_arr = Y.values

print('X_arr shape: ', X_arr.shape)
print('Y_arr shape: ', Y_arr.shape)
# Out:
# X_arr shape:  (5000, 6)
# Y_arr shape:  (5000,)

# %% [markdown]
# ## 4.4: Train and Test Split
#
# We will keep some part of the data aside as a __test__ set. The model will not use this set during training and it will be used only for checking the performance of the model in trained and un-trained states. This way, we can make sure that we are going in the right direction with our model training.

# %%
X_train, X_test, y_train, y_test = train_test_split(X_arr, Y_arr, test_size = 0.05, shuffle = True, random_state=0)

print('X_train shape: ', X_train.shape)
print('y_train shape: ', y_train.shape)
print('X_test shape: ', X_test.shape)
print('y_test shape: ', y_test.shape)
# Out:
# X_train shape:  (4750, 6)
# y_train shape:  (4750,)
# X_test shape:  (250, 6)
# y_test shape:  (250,)

# %% [markdown]
# # Task 5: Create the Model

# %% [markdown]
# ## 5.1: Create the Model
#
# Let's write a function that returns an untrained model of a certain architecture.

# %%
def get_model():
    
    model = Sequential([
        Dense(10, input_shape = (6,), activation = 'relu'),
        Dense(20, activation = 'relu'),
        Dense(5, activation = 'relu'),
        Dense(1)
    ])

    model.compile(
        loss='mse',
        optimizer='adadelta'
    )
    
    return model

model = get_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10)                70
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                220
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 105
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 401
# Trainable params: 401
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Task 6: Model Training

# %% [markdown]
# ## 6.1: Model Training
#
# We can use an `EarlyStopping` callback from Keras to stop the model training if the validation loss stops decreasing for a few epochs.

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience = 5)

model = get_model()

preds_on_untrained = model.predict(X_test)

history = model.fit(
    X_train, y_train,
    validation_data = (X_test, y_test),
    epochs = 1000,
    callbacks = [early_stopping]
)
# Out:
#  val_loss: 0.4022
# Epoch 809/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4488 - val_loss: 0.4016
# Epoch 810/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4480 - val_loss: 0.4009
# Epoch 811/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4472 - val_loss: 0.4003
# Epoch 812/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4465 - val_loss: 0.3997
# Epoch 813/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4457 - val_loss: 0.3991
# Epoch 814/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4449 - val_loss: 0.3984
# Epoch 815/1000
# 149/149 [==============================] - 0s 959us/step - loss: 0.4442 - val_loss: 0.3978
# Epoch 816/1000
# 149/149 [==============================] - 0s 2ms/step - loss: 0.4434 - val_loss: 0.3972
# Epoch 817/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4427 - val_loss: 0.3966
# Epoch 818/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4419 - val_loss: 0.3960
# Epoch 819/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4412 - val_loss: 0.3954
# Epoch 820/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4404 - val_loss: 0.3948
# Epoch 821/1000
# 149/149 [==============================] - 0s 2ms/step - loss: 0.4397 - val_loss: 0.3942
# Epoch 822/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4390 - val_loss: 0.3935
# Epoch 823/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4382 - val_loss: 0.3929
# Epoch 824/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4375 - val_loss: 0.3923
# Epoch 825/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4368 - val_loss: 0.3917
# Epoch 826/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4360 - val_loss: 0.3911
# Epoch 827/1000
# 149/149 [==============================] - 0s 2ms/step - loss: 0.4353 - val_loss: 0.3905
# Epoch 828/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4346 - val_loss: 0.3899
# Epoch 829/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4339 - val_loss: 0.3893
# Epoch 830/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4331 - val_loss: 0.3887
# Epoch 831/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4324 - val_loss: 0.3882
# Epoch 832/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4317 - val_loss: 0.3876
# Epoch 833/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4310 - val_loss: 0.3870
# Epoch 834/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4303 - val_loss: 0.3864
# Epoch 835/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4296 - val_loss: 0.3858
# Epoch 836/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4289 - val_loss: 0.3852
# Epoch 837/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4282 - val_loss: 0.3847
# Epoch 838/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4275 - val_loss: 0.3841
# Epoch 839/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4268 - val_loss: 0.3835
# Epoch 840/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4261 - val_loss: 0.3830
# Epoch 841/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4254 - val_loss: 0.3824
# Epoch 842/1000
# 149/149 [==============================] - 0s 957us/step - loss: 0.4247 - val_loss: 0.3818
# Epoch 843/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4241 - val_loss: 0.3813
# Epoch 844/1000
# 149/149 [==============================] - 0s 2ms/step - loss: 0.4234 - val_loss: 0.3807
# Epoch 845/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4227 - val_loss: 0.3802
# Epoch 846/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4220 - val_loss: 0.3796
# Epoch 847/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4213 - val_loss: 0.3791
# Epoch 848/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4207 - val_loss: 0.3785
# Epoch 849/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4200 - val_loss: 0.3780
# Epoch 850/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4194 - val_loss: 0.3775
# Epoch 851/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4187 - val_loss: 0.3769
# Epoch 852/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4180 - val_loss: 0.3764
# Epoch 853/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4174 - val_loss: 0.3758
# Epoch 854/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4167 - val_loss: 0.3753
# Epoch 855/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4160 - val_loss: 0.3748
# Epoch 856/1000
# 149/149 [==============================] - 0s 2ms/step - loss: 0.4154 - val_loss: 0.3742
# Epoch 857/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4147 - val_loss: 0.3737
# Epoch 858/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4141 - val_loss: 0.3731
# Epoch 859/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4134 - val_loss: 0.3726
# Epoch 860/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4128 - val_loss: 0.3721
# Epoch 861/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4121 - val_loss: 0.3716
# Epoch 862/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4115 - val_loss: 0.3711
# Epoch 863/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4109 - val_loss: 0.3705
# Epoch 864/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4103 - val_loss: 0.3700
# Epoch 865/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4096 - val_loss: 0.3695
# Epoch 866/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4090 - val_loss: 0.3690
# Epoch 867/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4084 - val_loss: 0.3685
# Epoch 868/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4078 - val_loss: 0.3680
# Epoch 869/1000
# 149/149 [==============================] - 0s 2ms/step - loss: 0.4072 - val_loss: 0.3675
# Epoch 870/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4065 - val_loss: 0.3670
# Epoch 871/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4059 - val_loss: 0.3665
# Epoch 872/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4053 - val_loss: 0.3660
# Epoch 873/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4047 - val_loss: 0.3655
# Epoch 874/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4041 - val_loss: 0.3650
# Epoch 875/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4035 - val_loss: 0.3645
# Epoch 876/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4029 - val_loss: 0.3640
# Epoch 877/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4023 - val_loss: 0.3635
# Epoch 878/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4017 - val_loss: 0.3630
# Epoch 879/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4011 - val_loss: 0.3625
# Epoch 880/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4005 - val_loss: 0.3620
# Epoch 881/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3998 - val_loss: 0.3615
# Epoch 882/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3993 - val_loss: 0.3610
# Epoch 883/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3987 - val_loss: 0.3606
# Epoch 884/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3981 - val_loss: 0.3601
# Epoch 885/1000
# 149/149 [==============================] - 0s 2ms/step - loss: 0.3975 - val_loss: 0.3596
# Epoch 886/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3969 - val_loss: 0.3591
# Epoch 887/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3963 - val_loss: 0.3586
# Epoch 888/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3957 - val_loss: 0.3582
# Epoch 889/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3951 - val_loss: 0.3577
# Epoch 890/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3946 - val_loss: 0.3572
# Epoch 891/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3940 - val_loss: 0.3568
# Epoch 892/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3934 - val_loss: 0.3563
# Epoch 893/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3928 - val_loss: 0.3559
# Epoch 894/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3923 - val_loss: 0.3554
# Epoch 895/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3917 - val_loss: 0.3550
# Epoch 896/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3912 - val_loss: 0.3545
# Epoch 897/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3906 - val_loss: 0.3540
# Epoch 898/1000
# 149/149 [==============================] - 0s 2ms/step - loss: 0.3900 - val_loss: 0.3536
# Epoch 899/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3894 - val_loss: 0.3531
# Epoch 900/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3889 - val_loss: 0.3527
# Epoch 901/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3883 - val_loss: 0.3522
# Epoch 902/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3877 - val_loss: 0.3517
# Epoch 903/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3872 - val_loss: 0.3513
# Epoch 904/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3866 - val_loss: 0.3508
# Epoch 905/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3861 - val_loss: 0.3504
# Epoch 906/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3855 - val_loss: 0.3500
# Epoch 907/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3850 - val_loss: 0.3495
# Epoch 908/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3844 - val_loss: 0.3491
# Epoch 909/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3839 - val_loss: 0.3487
# Epoch 910/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3833 - val_loss: 0.3482
# Epoch 911/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3828 - val_loss: 0.3478
# Epoch 912/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3823 - val_loss: 0.3474
# Epoch 913/1000
# 149/149 [==============================] - 0s 2ms/step - loss: 0.3817 - val_loss: 0.3469
# Epoch 914/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3812 - val_loss: 0.3465
# Epoch 915/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3806 - val_loss: 0.3461
# Epoch 916/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3801 - val_loss: 0.3457
# Epoch 917/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3796 - val_loss: 0.3453
# Epoch 918/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3791 - val_loss: 0.3448
# Epoch 919/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3786 - val_loss: 0.3444
# Epoch 920/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3780 - val_loss: 0.3440
# Epoch 921/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3775 - val_loss: 0.3436
# Epoch 922/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3770 - val_loss: 0.3432
# Epoch 923/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3765 - val_loss: 0.3428
# Epoch 924/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3760 - val_loss: 0.3424
# Epoch 925/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3754 - val_loss: 0.3420
# Epoch 926/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3749 - val_loss: 0.3416
# Epoch 927/1000
# 149/149 [==============================] - 0s 2ms/step - loss: 0.3744 - val_loss: 0.3412
# Epoch 928/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3739 - val_loss: 0.3408
# Epoch 929/1000
# 149/149 [==============================] - 0s 986us/step - loss: 0.3734 - val_loss: 0.3404
# Epoch 930/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3729 - val_loss: 0.3400
# Epoch 931/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3724 - val_loss: 0.3396
# Epoch 932/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3719 - val_loss: 0.3392
# Epoch 933/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3714 - val_loss: 0.3388
# Epoch 934/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3709 - val_loss: 0.3384
# Epoch 935/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3704 - val_loss: 0.3380
# Epoch 936/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3699 - val_loss: 0.3376
# Epoch 937/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3694 - val_loss: 0.3372
# Epoch 938/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3689 - val_loss: 0.3368
# Epoch 939/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3685 - val_loss: 0.3364
# Epoch 940/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3680 - val_loss: 0.3361
# Epoch 941/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3675 - val_loss: 0.3357
# Epoch 942/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3670 - val_loss: 0.3353
# Epoch 943/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3666 - val_loss: 0.3349
# Epoch 944/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3661 - val_loss: 0.3346
# Epoch 945/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3656 - val_loss: 0.3342
# Epoch 946/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3651 - val_loss: 0.3338
# Epoch 947/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3647 - val_loss: 0.3335
# Epoch 948/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3642 - val_loss: 0.3331
# Epoch 949/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3637 - val_loss: 0.3327
# Epoch 950/1000
# 149/149 [==============================] - 0s 996us/step - loss: 0.3633 - val_loss: 0.3324
# Epoch 951/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3628 - val_loss: 0.3320
# Epoch 952/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3624 - val_loss: 0.3316
# Epoch 953/1000
# 149/149 [==============================] - 0s 1000us/step - loss: 0.3619 - val_loss: 0.3313
# Epoch 954/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3615 - val_loss: 0.3309
# Epoch 955/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3610 - val_loss: 0.3306
# Epoch 956/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3606 - val_loss: 0.3302
# Epoch 957/1000
# 149/149 [==============================] - 0s 2ms/step - loss: 0.3601 - val_loss: 0.3299
# Epoch 958/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3597 - val_loss: 0.3295
# Epoch 959/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3593 - val_loss: 0.3292
# Epoch 960/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3588 - val_loss: 0.3288
# Epoch 961/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3584 - val_loss: 0.3285
# Epoch 962/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3579 - val_loss: 0.3281
# Epoch 963/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3575 - val_loss: 0.3278
# Epoch 964/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3571 - val_loss: 0.3275
# Epoch 965/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3567 - val_loss: 0.3271
# Epoch 966/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3563 - val_loss: 0.3268
# Epoch 967/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3558 - val_loss: 0.3265
# Epoch 968/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3554 - val_loss: 0.3261
# Epoch 969/1000
# 149/149 [==============================] - 0s 997us/step - loss: 0.3550 - val_loss: 0.3258
# Epoch 970/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3545 - val_loss: 0.3254
# Epoch 971/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3541 - val_loss: 0.3251
# Epoch 972/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3537 - val_loss: 0.3248
# Epoch 973/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3533 - val_loss: 0.3245
# Epoch 974/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3529 - val_loss: 0.3241
# Epoch 975/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3525 - val_loss: 0.3238
# Epoch 976/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3521 - val_loss: 0.3235
# Epoch 977/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3517 - val_loss: 0.3232
# Epoch 978/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3513 - val_loss: 0.3228
# Epoch 979/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3509 - val_loss: 0.3225
# Epoch 980/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3505 - val_loss: 0.3222
# Epoch 981/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3501 - val_loss: 0.3219
# Epoch 982/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3497 - val_loss: 0.3216
# Epoch 983/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3493 - val_loss: 0.3213
# Epoch 984/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3489 - val_loss: 0.3209
# Epoch 985/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3485 - val_loss: 0.3206
# Epoch 986/1000
# 149/149 [==============================] - 0s 2ms/step - loss: 0.3481 - val_loss: 0.3203
# Epoch 987/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3477 - val_loss: 0.3200
# Epoch 988/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3473 - val_loss: 0.3197
# Epoch 989/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3469 - val_loss: 0.3194
# Epoch 990/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3466 - val_loss: 0.3191
# Epoch 991/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3462 - val_loss: 0.3188
# Epoch 992/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3458 - val_loss: 0.3185
# Epoch 993/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3454 - val_loss: 0.3181
# Epoch 994/1000
# 149/149 [==============================] - 0s 2ms/step - loss: 0.3450 - val_loss: 0.3178
# Epoch 995/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3447 - val_loss: 0.3175
# Epoch 996/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3443 - val_loss: 0.3172
# Epoch 997/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3439 - val_loss: 0.3169
# Epoch 998/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3435 - val_loss: 0.3166
# Epoch 999/1000
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3432 - val_loss: 0.3163
# Epoch 1000/1000
# 149/149 [==============================] - 0s 2ms/step - loss: 0.3428 - val_loss: 0.3161

# %% [markdown]
# ## 6.2: Plot Training and Validation Loss
#
# Let's use the `plot_loss` helper function to take a look training and validation loss.

# %%
plot_loss(history)

# %% [markdown]
# # Task 7: Predictions

# %% [markdown]
# ## 7.1: Plot Raw Predictions
#
# Let's use the `compare_predictions` helper function to compare predictions from the model when it was untrained and when it was trained.

# %%
preds_on_trained = model.predict(X_test)

compare_predictions(preds_on_untrained, preds_on_trained, y_test)

# %% [markdown]
# ## 7.2: Plot Price Predictions
#
# The plot for price predictions and raw predictions will look the same with just one difference: The x and y axis scale is changed.

# %%
price_on_untrained = [convert_label_value(y) for y in preds_on_untrained]
price_on_trained = [convert_label_value(y) for y in preds_on_trained]
price_y_test = [convert_label_value(y) for y in y_test]

compare_predictions(price_on_untrained, price_on_trained, price_y_test)
